# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshopShrivastava/Pandas/blob/main/Assignment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Assignment 1 Question 7**

# %%
import pandas as pd
import matplotlib.pyplot as plt
Data = pd.read_csv('/content/Q7.csv')
Data
# Out:
#              Unnamed: 0  Points  Score  Weigh
# 0             Mazda RX4    3.90  2.620  16.46
# 1         Mazda RX4 Wag    3.90  2.875  17.02
# 2            Datsun 710    3.85  2.320  18.61
# 3        Hornet 4 Drive    3.08  3.215  19.44
# 4     Hornet Sportabout    3.15  3.440  17.02
# 5               Valiant    2.76  3.460  20.22
# 6            Duster 360    3.21  3.570  15.84
# 7             Merc 240D    3.69  3.190  20.00
# 8              Merc 230    3.92  3.150  22.90
# 9              Merc 280    3.92  3.440  18.30
# 10            Merc 280C    3.92  3.440  18.90
# 11           Merc 450SE    3.07  4.070  17.40
# 12           Merc 450SL    3.07  3.730  17.60
# 13          Merc 450SLC    3.07  3.780  18.00
# 14   Cadillac Fleetwood    2.93  5.250  17.98
# 15  Lincoln Continental    3.00  5.424  17.82
# 16    Chrysler Imperial    3.23  5.345  17.42
# 17             Fiat 128    4.08  2.200  19.47
# 18          Honda Civic    4.93  1.615  18.52
# 19       Toyota Corolla    4.22  1.835  19.90
# 20        Toyota Corona    3.70  2.465  20.01
# 21     Dodge Challenger    2.76  3.520  16.87
# 22          AMC Javelin    3.15  3.435  17.30
# 23           Camaro Z28    3.73  3.840  15.41
# 24     Pontiac Firebird    3.08  3.845  17.05
# 25            Fiat X1-9    4.08  1.935  18.90
# 26        Porsche 914-2    4.43  2.140  16.70
# 27         Lotus Europa    3.77  1.513  16.90
# 28       Ford Pantera L    4.22  3.170  14.50
# 29         Ferrari Dino    3.62  2.770  15.50
# 30        Maserati Bora    3.54  3.570  14.60
# 31           Volvo 142E    4.11  2.780  18.60

# %%
#print(Data.Points.mean())
print(Data.Points.median())
print(Data.Score.median())
print(Data.Weigh.median())
# Out:
# 3.6950000000000003
# 3.325
# 17.71

# %%
print(Data.Points.var())
print(Data.Score.var())
print(Data.Weigh.var())
# Out:
# 0.28588135080645166
# 0.9573789677419354
# 3.193166129032258

# %%
Data.Points.mode()
# Out:
# 0    3.07
# 1    3.92
# dtype: float64

# %%
Data.Score.mode()
# Out:
# 0    3.44
# dtype: float64

# %%
Data.Weigh.mode()
# Out:
# 0    17.02
# 1    18.90
# dtype: float64

# %%
Points_Range = Data.Points.max() - Data.Points.min()
print(Points_Range)
# Out:
# 2.17

# %%
Score_Range=Data.Score.max()-Data.Score.min()
Score_Range
# Out:
# 3.9109999999999996

# %%
Weigh_Range=Data.Weigh.max()-Data.Weigh.min()
Weigh_Range
# Out:
# 8.399999999999999

# %%
plt.boxplot(Data.Points)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f7118e6b290>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f7118e1fbd0>,
#   <matplotlib.lines.Line2D at 0x7f7118e1f110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7118e73510>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f711930ccd0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f711f9466d0>,
#   <matplotlib.lines.Line2D at 0x7f7118eead50>]}

# %%
plt.hist(Data.Points)
# Out:
# (array([3., 8., 2., 2., 4., 6., 5., 1., 0., 1.]),
#  array([2.76 , 2.977, 3.194, 3.411, 3.628, 3.845, 4.062, 4.279, 4.496,
#         4.713, 4.93 ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(Data.Score)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f71188a1490>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f71188942d0>,
#   <matplotlib.lines.Line2D at 0x7f7118893110>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f71188937d0>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f71188938d0>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f7118894d10>,
#   <matplotlib.lines.Line2D at 0x7f71188948d0>]}

# %%
plt.hist(Data.Score)
# Out:
# (array([3., 3., 3., 3., 9., 7., 1., 0., 0., 3.]),
#  array([1.513 , 1.9041, 2.2952, 2.6863, 3.0774, 3.4685, 3.8596, 4.2507,
#         4.6418, 5.0329, 5.424 ]),
#  <a list of 10 Patch objects>)

# %%
plt.boxplot(Data.Weigh)
# Out:
# {'boxes': [<matplotlib.lines.Line2D at 0x7f71187a08d0>],
#  'caps': [<matplotlib.lines.Line2D at 0x7f71187a1fd0>,
#   <matplotlib.lines.Line2D at 0x7f71187a1190>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f7118802490>],
#  'means': [],
#  'medians': [<matplotlib.lines.Line2D at 0x7f711879e650>],
#  'whiskers': [<matplotlib.lines.Line2D at 0x7f711879c750>,
#   <matplotlib.lines.Line2D at 0x7f71187a1b50>]}

# %%
plt.hist(Data.Weigh)
# Out:
# (array([2., 3., 4., 8., 6., 4., 4., 0., 0., 1.]),
#  array([14.5 , 15.34, 16.18, 17.02, 17.86, 18.7 , 19.54, 20.38, 21.22,
#         22.06, 22.9 ]),
#  <a list of 10 Patch objects>)

# %%
Data.describe()
# Out:
#           Points      Score      Weigh
# count  32.000000  32.000000  32.000000
# mean    3.596563   3.217250  17.848750
# std     0.534679   0.978457   1.786943
# min     2.760000   1.513000  14.500000
# 25%     3.080000   2.581250  16.892500
# 50%     3.695000   3.325000  17.710000
# 75%     3.920000   3.610000  18.900000
# max     4.930000   5.424000  22.900000
