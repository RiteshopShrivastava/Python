# %% [markdown]
# <a href="https://colab.research.google.com/github/RiteshopShrivastava/Exercise/blob/main/Normal_Disribution.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
beml_df = pd.read_csv("BEML.csv")
beml_df[0:5]
# Out:
#          Date    Open     High  ...    Close  Total Trade Quantity  Turnover (Lacs)
# 0  2010-01-04  1121.0  1151.00  ...  1135.60              101651.0          1157.18
# 1  2010-01-05  1146.8  1149.00  ...  1134.60               59504.0           676.47
# 2  2010-01-06  1140.0  1164.25  ...  1139.60              128908.0          1482.84
# 3  2010-01-07  1142.0  1159.40  ...  1144.15              117871.0          1352.98
# 4  2010-01-08  1156.0  1172.00  ...  1144.05              170063.0          1971.42
#
# [5 rows x 8 columns]

# %%
glaxo_df = pd.read_csv("GLAXO.csv")
glaxo_df[0:5]
# Out:
#          Date     Open     High  ...    Close  Total Trade Quantity  Turnover (Lacs)
# 0  2010-01-04  1613.00  1629.10  ...  1625.65                9365.0           151.74
# 1  2010-01-05  1639.95  1639.95  ...  1616.80               38148.0           622.58
# 2  2010-01-06  1618.00  1644.00  ...  1638.50               36519.0           595.09
# 3  2010-01-07  1645.00  1654.00  ...  1648.70               12809.0           211.00
# 4  2010-01-08  1650.00  1650.00  ...  1639.80               28035.0           459.11
#
# [5 rows x 8 columns]

# %%
beml_df = beml_df[['Date', 'Close']]
glaxo_df = glaxo_df[['Date', 'Close']]

# %%
beml_df
# Out:
#             Date    Close
# 0     2010-01-04  1135.60
# 1     2010-01-05  1134.60
# 2     2010-01-06  1139.60
# 3     2010-01-07  1144.15
# 4     2010-01-08  1144.05
# ...          ...      ...
# 1734  2016-12-26   950.25
# 1735  2016-12-27   975.70
# 1736  2016-12-28   974.40
# 1737  2016-12-29   986.05
# 1738  2016-12-30  1000.60
#
# [1739 rows x 2 columns]

# %%
'''The DataFrames have a date column, so we can
create a DatetimeIndex index from this column Date. It will ensure that the rows are sorted by time in
ascending order.'''
glaxo_df = glaxo_df.set_index(pd.DatetimeIndex(glaxo_df['Date']))
#glaxo_df = glaxo_df.set_index(pd.DatetimeIndex(glaxo_df.Date))
beml_df = beml_df.set_index(pd.DatetimeIndex(beml_df['Date']))

# %%
import matplotlib.pyplot as plt
import seaborn as sn
# %matplotlib inline
plt.plot(glaxo_df.Close);
plt.xlabel('Time');
plt.ylabel('Close Price');

# %%
glaxo_df
# Out:
#                   Date    Close
# Date
# 2010-01-04  2010-01-04  1625.65
# 2010-01-05  2010-01-05  1616.80
# 2010-01-06  2010-01-06  1638.50
# 2010-01-07  2010-01-07  1648.70
# 2010-01-08  2010-01-08  1639.80
# ...                ...      ...
# 2016-12-26  2016-12-26  2723.50
# 2016-12-27  2016-12-27  2701.75
# 2016-12-28  2016-12-28  2702.15
# 2016-12-29  2016-12-29  2727.90
# 2016-12-30  2016-12-30  2729.80
#
# [1739 rows x 2 columns]

# %%
plt.plot(beml_df.Close);
plt.xlabel('Time');
plt.ylabel('Close');

# %%
glaxo_df['gain'] = glaxo_df.Close.pct_change(periods = 1)
beml_df['gain'] = beml_df.Close.pct_change(periods = 1)

# %%
glaxo_df
# Out:
#                   Date    Close      gain
# Date
# 2010-01-04  2010-01-04  1625.65       NaN
# 2010-01-05  2010-01-05  1616.80       NaN
# 2010-01-06  2010-01-06  1638.50  0.007905
# 2010-01-07  2010-01-07  1648.70  0.019730
# 2010-01-08  2010-01-08  1639.80  0.000793
# ...                ...      ...       ...
# 2016-12-26  2016-12-26  2723.50  0.003685
# 2016-12-27  2016-12-27  2701.75 -0.009259
# 2016-12-28  2016-12-28  2702.15 -0.007839
# 2016-12-29  2016-12-29  2727.90  0.009679
# 2016-12-30  2016-12-30  2729.80  0.010233
#
# [1739 rows x 3 columns]

# %%
#drop first row since it is NaN
glaxo_df = glaxo_df.dropna()
beml_df = beml_df.dropna()

# %%
#Plot the gains
import matplotlib.pyplot as plt

plt.figure(figsize = (8, 6));
plt.plot(glaxo_df.index, glaxo_df.gain);
plt.xlabel('Time');
plt.ylabel('gain');

# %%
import seaborn as sn
sn.distplot(glaxo_df.gain, label = 'Glaxo');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sn.distplot(beml_df.gain, label = 'BEML');
plt.xlabel('gain');
plt.ylabel('Density');
plt.legend();
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
print('Mean:', round(glaxo_df.gain.mean(), 4))
print('Standard Deviation: ', round(glaxo_df.gain.std(), 4))
# Out:
# Mean: 0.0004
# Standard Deviation:  0.0134

# %%
print('Mean: ', round(beml_df.gain.mean(), 4))
print('Standard Deviation: ', round(beml_df.gain.std(), 4))
# Out:
# Mean:  0.0003
# Standard Deviation:  0.0264

# %%
from scipy import stats
#Probability of making 2% loss or higher in Glaxo
stats.norm.cdf( -0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())
# Out:
# 0.06352488667177397

# %%
#Probability of making 2% gain or higher in Glaxo
1 - stats.norm.cdf(0.02,
loc=glaxo_df.gain.mean(),
scale=glaxo_df.gain.std())
# Out:
# 0.07104511457618568

# %% [markdown]
# ### Inclass Exercise

# %% [markdown]
# ### Compute 2% loss or gain for BEML

# %%
from scipy import stats
#Probability of making 2% loss or higher in BEML
stats.norm.cdf( -0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22155987503755292

# %%
#Probability of making 2% gain or higher in BEML
1- stats.norm.cdf( 0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
# Out:
# 0.22769829484075343

# %%
#Probability of making 2% gain or higher in BEML
1 - stats.norm.cdf(0.02,
loc=beml_df.gain.mean(),
scale=beml_df.gain.std())
